# %% [markdown]
# ## Import data

# %%
import pandas as pd
ATAC = pd.read_csv("data/1.ATAC-Seq data.CSV", sep=";")

# %% [markdown]
# # Adjust data

# %%
ATAC.head()
# Out:
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_1  chr1  3020786                         0.00
# 1  ImmGenATAC1219.peak_2  chr1  3087226                         0.00
# 2  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 3  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 4  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0                0.56                              NaN  NaN
# 1                0.50                              NaN  NaN
# 2            45879.00                              1.0  NaN
# 3            45691.00                              1.0  NaN
# 4            11324.00                              NaN  NaN
#
#   genes.within.100Kb  LTHSC.34-.BM  LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  \
# 0                NaN          0.41          0.71  ...      0.10      0.10
# ...

# %%
ATAC.shape
# Out:
# (512595, 98)

# %%
#ersten Spalten ?? entfernen, um nur numerische Daten zu haben 
ATAC_num = ATAC.iloc[:, 2:]

# %%
ATAC_num.head()
# Out:
#     Summit  mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 0  3020786                         0.00                0.56
# 1  3087226                         0.00                0.50
# 2  3120109                         0.07            45879.00
# 3  3121485                         0.15            45691.00
# 4  3372787                         0.03            11324.00
#
#    Included.in.systematic.analysis  TSS genes.within.100Kb  LTHSC.34-.BM  \
# 0                              NaN  NaN                NaN          0.41
# 1                              NaN  NaN                NaN          0.41
# 2                              1.0  NaN                NaN      13181.00
# 3                              1.0  NaN                NaN          0.41
# 4                              NaN  NaN                NaN          0.41
#
#    LTHSC.34+.BM  STHSC.150-.BM  MPP4.135+.BM  ...  DC.4+.Sp  DC.8+.Sp  \
# 0          0.71           0.90          0.11  ...      0.10      0.10
# ...

# %%
ATAC_num.shape
# Out:
# (512595, 96)

# %% [markdown]
# ## Clustering
