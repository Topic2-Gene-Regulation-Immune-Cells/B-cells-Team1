# %%
import pandas as pd
import numpy as np
ATAC = pd.read_csv("data/1.ATAC-Seq data.CSV", sep=";")
QC_RD = pd.read_csv("data/ATAC_QCmatric_ReadStatistics.csv", sep=";")
QC_RD.head()
# Out:
#   ImmGen.lab.contributed         sample.name population.name  total.reads  \
# 0                 Wagers   LTHSC.34-.BM.rep1    LTHSC.34-.BM     30846074
# 1                 Wagers   LTHSC.34-.BM.rep2    LTHSC.34-.BM     12221064
# 2                 Wagers   LTHSC.34+.BM.rep1    LTHSC.34+.BM     18001678
# 3                 Wagers   LTHSC.34+.BM.rep2    LTHSC.34+.BM     20921592
# 4                 Wagers  STHSC.150-.BM.rep1   STHSC.150-.BM     26562826
#
#   overal_ alignment_rate%  mapped_MAPQ5  reads.after.removing.duplication  \
# 0                   56,32      16524909                          10069268
# 1                   55,26       6432458                           4424534
# 2                   61,14      10460447                           6606793
# 3                   61,41      12255655                           8074178
# 4                    55,4      14008223                           8315375
#
#    properly_paired.reads  paired.count  total.Htseq-count.on.genes
# ...

# %%
QC_RD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ImmGen.lab.contributed            169 non-null    object
#  1   sample.name                       169 non-null    object
#  2   population.name                   169 non-null    object
#  3   total.reads                       169 non-null    int64
#  4   overal_ alignment_rate%           169 non-null    object
#  5   mapped_MAPQ5                      169 non-null    int64
#  6   reads.after.removing.duplication  169 non-null    int64
#  7   properly_paired.reads             169 non-null    int64
#  8   paired.count                      169 non-null    int64
#  9   total.Htseq-count.on.genes        169 non-null    int64
# dtypes: int64(6), object(4)
# memory usage: 13.3+ KB

# %%
QC_RD.shape
# Out:
# (169, 10)

# %%
QC_RD.describe(include='all')
# Out:
#        ImmGen.lab.contributed        sample.name population.name  \
# count                     169                169             169
# unique                     13                169              86
# top                      CBDM  LTHSC.34-.BM.rep1         B.Fo.Sp
# freq                       45                  1               4
# mean                      NaN                NaN             NaN
# std                       NaN                NaN             NaN
# min                       NaN                NaN             NaN
# 25%                       NaN                NaN             NaN
# 50%                       NaN                NaN             NaN
# 75%                       NaN                NaN             NaN
# max                       NaN                NaN             NaN
#
#          total.reads overal_ alignment_rate%  mapped_MAPQ5  \
# count   1.690000e+02                     169  1.690000e+02
# unique           NaN                     161           NaN
# ...
